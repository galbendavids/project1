# %% [markdown]
# <a href="https://colab.research.google.com/github/galbendavids/project1/blob/master/thesis_table_1_and_first_modelling_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#try 4 


#case control devide

#look for the right values in the those columns
import pandas as pd
import re

#if run in ssh
dest_data= pd.read_csv('/gpfs0/bgu-nadavrap/users/galbend/dest_data0602.csv')
#if runs here
#dest_data= pd.read_csv('/content/dest_data0602.csv',nrows=1000)

dest_data['NAFLD-IND']="UNKNOWN"
dest_data['icd_relevant_values']=""
dest_data['icd_codes']=""
dest_data['icd_other_codes']=""



for index in range(len(dest_data)):
  string=""

  icd_codes=set()
  relevant_values=set()
  for column in list(dest_data.columns):
    value=str(dest_data.at[index,column])
    icd_codes.add(value)

  dest_data.at[index,'icd_codes']=icd_codes
  case=False #unless we discover else
  ##case
  if 'K758' in icd_codes:
    print(index)
    case=True
    relevant_values.add('K758')
    icd_codes.remove('K758')

  if 'K760' in icd_codes:
    print(index)
    case=True
    relevant_values.add('K760')
    icd_codes.remove('K760')

  if 'K769' in icd_codes:
    print(index)
    case=True
    relevant_values.add('K769')
    icd_codes.remove('K769')

  control=True #unless we discover else

  if case==True:
    dest_data.at[index,'NAFLD-IND']="NAFLD-IND"
    
  #control
  if case==False:
    for element in icd_codes:
      line_loc=element.find('K7',0,-1)
      if line_loc>=0: #means that it has founded the k7..
        control=False
        relevant_values.add(value)
    
      k76=dest_data.at[index,'131671-0.0']
      if k76>0:
        control=False
        relevant_values.add('K76')
    

  if control==True:
    if case==False:
      dest_data.at[index,'NAFLD-IND']="CONTROL"   
    dest_data.at[index,'icd_relevant_values']=relevant_values
    dest_data.at[index,'icd_other_codes']=icd_codes



dest_data.to_csv("dest_data_new.csv", index=False)

#there is a bug here. for some reason - the nafld group is unfound..
#after that - check that its ok..
#after that - join with other table

# %%
columns=['eid','NAFLD-IND','icd_codes','icd_other_codes']
dest_data= pd.read_csv('/gpfs0/bgu-nadavrap/users/galbend/dest_data0602.csv',usecols=columns)

dest_data_new['NAFLD-IND'].value_counts()

# %%
#run on ssh "create_df_for_table1-10.py" 
import pandas as pd
columns=['eid','NAFLD-IND','icd_codes','icd_other_codes']
dest= pd.read_csv('/gpfs0/bgu-nadavrap/users/galbend/dest_data_new.csv',usecols=columns)
print("complete part")
data=pd.read_csv('/gpfs0/bgu-nadavrap/users/galbend/UKBB/data/ukb41487.csv',usecols=
                 ['eid',
                  '1200-0.0',
                  '1239-0.0',
                  '1349-0.0',
                            
                  '31-0.0',
                  '34-0.0',
                  "21001-0.0",
                  "21002-0.0",
                  "51-0.0",
                  "50-0.0",
                  "93-0.0",
                  "94-0.0",
                  "95-0.0",
                  "48-0.0",
                  "49-0.0",
                  "30670-0.0",
                  "30870-0.0",

                  "131289-0.0",

                   "130707-0.0",
                   "130709-0.0",
                            
                   "130715-0.0",
                   "131963-0.0",
                   "131965-0.0",
                   "130793-0.0",
                   "130823-0.0",

                   "130695-0.0",
                   "130697-0.0",
                            
                   "104920-1.0",

                   "884-0.0",
                   "904-0.0",
                   "971-0.0",
                   "991-0.0",
                            
                   "1528-0.0",
                   "1558-0.0",
                   "1389-0.0",
                   "1379-0.0",
                   "1369-0.0",
                            
                   "1349-0.0",
                   "1329-0.0",
                   "1339-0.0",
                   "1359-0.0",
                   "1309-0.0",
                   "1299-0.0",
                   "1588-0.0",
                   "102460-0.0",
                   "102480-0.0",
                   "100520-0.0",


                   "132398-0.0",
                   "6155-0.0",
                            

                            
                    "1050-0.0",
                    "20517-0.0",
                    "20519-0.0",
                    "1160-0.0",
                    "1200-0.0",
                            
                    "1190-0.0",
                    "1210-0.0",
                            
                    "22604-0.0",
                            
                    "1279-0.0",
                    "1269-0.0",
                    "1239-0.0",
                    "1249-0.0",
                    "6160-0.0", 
                    "20446-0.0",
                    "20510-0.0",
                    '2050-0.0',
                    "2090-0.0",
                    "2100-0.0",
                    "20417-0.0",
                    "20506-0.0",
                    "20509-0.0",
                    "20515-0.0",
                    "20520-0.0",

                    "131783-0.0",
                    "21051-0.0",
                    "131053-0.0",
                            
                     "6152-0.0",
                     "131791-0.0",
                            
                     "131241-0.0",
                     "131369-0.0",
                     "131431-0.0",
                     "131475-0.0",
                     "131495-0.0",
                     "131735-0.0",

                     "22502-0.0",

                     "131447-0.0",

                     "21052-0.0",


                           
                     "131627-0.0",
                     "131629-0.0",
                     "130231-0.0",
                     "6154-0.0",
                     "130195-0.0",
                     "130197-0.0",
                     "130199-0.0",

                     "132085-0.0",
                     "132157-0.0",
                     "6153-0.0",
                            
                     "131403-0.0",
                     "131409-0.0",
                     "131743-0.0",
                     "131775-0.0",
                     '2178-0.0',
                     "131447-0.0"

                  ]
                 )

data.to_csv("data_frame_for_tableone.csv")
print("complete part")



print ("size data:")
print(data.shape)
print("size dest:")
print(dest.shape)

df_merge= pd.concat([data, dest], axis=1)
print("size merge:")
print(df_merge.shape)

print("complete part")
df_merge.to_csv("mergerd_data_frame_for_tableone.csv")

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e2280ed87269> in <module>()
#       1 #run on ssh "create_df_for_table1-9.py"
#       2 import pandas as pd
# ----> 3 dest=pd.read_csv('/gpfs0/bgu-nadavrap/users/galbend/ICD10_ukbb_new.csv',usecols=['K760'])
#       4 print("complete part")
#       5 data=pd.read_csv('/gpfs0/bgu-nadavrap/users/galbend/UKBB/data/ukb41487.csv',usecols=
#
# ...

# %%
"""

 scp -r galbend@sge250.bgu.ac.il:/gpfs0/bgu-nadavrap/users/galbend/mergerd_data_frame_for_tableone.csv  /Users/galbd/Desktop/table-1/


"""
# Out:
# '\n\n scp -r galbend@sge250.bgu.ac.il:/gpfs0/bgu-nadavrap/users/galbend/mergerd_data_frame_for_tableone.csv  /Users/galbd/Desktop/table-1/\n\n\n'

# %%
from sklearn import preprocessing
import pandas as pd


data=pd.read_csv("mergerd_data_frame_for_tableone.csv")
'''
data['K760']=data['K760'].replace([2],'NAFLD ind')
data['K760']=data['K760'].replace([1],'control group')
data['K760']=data['K760'].fillna('control group')
'''


data = data.rename(columns={'1200-0.0':'sleeping problems',
                            '1239-0.0':'Current tobacco smoking',
                            '1349-0.0':'consumes proccesed meat',
                            
                            '31-0.0': 'sex',
                            '34-0.0': 'YearOfBirth',
                            "21001-0.0": 'BMI',
                            "21002-0.0":'Weight',
                            "51-0.0":'Seated height',
                            "50-0.0":'Standing height',
                            "93-0.0":'Systolic blood pressure',
                            "94-0.0":'Diastolic blood pressure',
                            "95-0.0":'Pulse rate',
                            "48-0.0":'Waist circumference',
                            "49-0.0":'Hip circumference',
                            "30670-0.0":'Urea',
                            "30870-0.0":'Triglycerides',

                            "131289-0.0":'hypertensive heart disease',

                            "130707-0.0":'insulin-dependent diabetes mellitus',
                            "130709-0.0":'non-insulin-dependent diabetes mellitus',
                            
                            "130715-0.0":'unspecified diabetes mellitus',
                            "131963-0.0":'osteoporosis with pathological fracture',
                            "131965-0.0":'osteoporosis without pathological fracture',
                            "130793-0.0":'obesity',
                            "130823-0.0":'cystic fibrosis',

                            "130695-0.0":'subclinical iodine-deficiency hypothyroidism',
                            "130697-0.0":'other hypothyroidism',
                            
                            "104920-1.0":'Time spent doing light physical activity',

                            "884-0.0":'Number of days/week of moderate physical activity 10+ minutes',
                            "904-0.0":'Number of days/week of vigorous physical activity 10+ minutes',
                            "971-0.0":'Frequency of walking for pleasure in last 4 weeks',
                            "991-0.0":'Frequency of strenuous sports in last 4 weeks',
                            
                            "1528-0.0":'Water intake',
                            "1558-0.0":'Alcohol intake frequency',
                            "1389-0.0":'Pork intake',
                            "1379-0.0":'Lamb/mutton intake',
                            "1369-0.0":'Beef intake',
                            
                            "1349-0.0":'Processed meat intake',
                            "1329-0.0":'Oily fish intake',
                            "1339-0.0":'Non-oily fish intake',
                            "1359-0.0":'Poultry intake',
                            "1309-0.0":'Fresh fruit intake',
                            "1299-0.0":'Salad / raw vegetable intake',
                            "1588-0.0":'Average weekly beer plus cider intake',
                            "102460-0.0":'Crisp intake',
                            "102480-0.0":'Cheesy biscuits intake',
                            "100520-0.0":'Milk intake',


                            "132398-0.0":'transitory neonatal disorders of calcium and magnesium metabolism',
                            "6155-0.0":'Vitamin and mineral supplements',
                            

                            
                            "1050-0.0":'Time spend outdoors in summer',
                            "20517-0.0":'Trouble falling or staying asleep, or sleeping too much',
                            "20519-0.0":'Recent feelings of tiredness or low energy',
                            "1160-0.0":'Sleep duration',
                            "1200-0.0":'Sleeplessness / insomnia',
                            
                            "1190-0.0":'Nap during day',
                            "1210-0.0":'Snoring',
                            
                            "22604-0.0":'Work hours - lumped category-0',
                            
                            "1279-0.0":'Exposure to tobacco smoke outside home',
                            "1269-0.0":'Exposure to tobacco smoke at home',
                            "1239-0.0":'Current tobacco smoking',
                            "1249-0.0":'Past tobacco smoking',
                            "6160-0.0":'Leisure/social activities-0', 
                            "20446-0.0":'Ever had prolonged feelings of sadness or depression',
                            "20510-0.0":'Recent feelings of depression',
                            '2050-0.0':'Frequency of depressed mood in last 2 weeks',
                            "2090-0.0":'Seen doctor (GP) for nerves, anxiety, tension or depression',
                            "2100-0.0":'Seen a psychiatrist for nerves, anxiety, tension or depression',
                            "20417-0.0":'Tense, sore, or aching muscles during worst period of anxiety',
                            "20506-0.0":'Recent feelings of nervousness or anxiety',
                            "20509-0.0":'Recent inability to stop or control worrying',
                            "20515-0.0":'Recent trouble relaxing',
                            "20520-0.0":'Recent worrying too much about different things',

                            "131783-0.0":'other nonscarring hair loss',
                            "21051-0.0":'Degree bothered by headaches in the last 3 months',
                            "131053-0.0":'migraine',
                            
                            "6152-0.0":'Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor',
                            "131791-0.0":'acne',
                            
                            "131241-0.0":'cholesteatoma of middle ear',
                            "131369-0.0":'stroke, not specified as haemorrhage or infarction',
                            "131431-0.0":'acute tonsillitis',
                            "131475-0.0":'chronic diseases of tonsils and adenoids',
                            "131495-0.0":'asthma',
                            "131735-0.0":'dermatitis due to substances taken internally',
                            "131447-0.0":'pneumonia due to streptococcus pneumoniae',
                            "22502-0.0":'Cough on most days',

                            "131447-0.0":'pneumonia due to streptococcus pneumoniae',

                            "21052-0.0":'Degree bothered by chest pain in the last 3 months',


                           
                            "131627-0.0":'crohns disease',
                            "131629-0.0":'ulcerative colitis',
                            "130231-0.0":'candidiasis',
                            "6154-0.0":'Medication for pain relief, constipation, heartburn',
                            "130195-0.0":'acute hepatitis a',
                            "130197-0.0":'acute hepatitis b',
                            "130199-0.0":'other acute viral hepatitis',

                            "132085-0.0":'male infertility',
                            "132157-0.0":'female infertility',
                            "6153-0.0":'Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones',
                            
                            "131403-0.0":'varicose veins of lower extremities',
                            "131409-0.0":'varicose veins of other sites',
                            "131743-0.0":'psoriasis',
                            "131775-0.0":'nail disorders',
                            '2178-0.0':'overall health'
                            
})



data['overall health']=data['overall health'].replace([1,2],'good+')
data['overall health']=data['overall health'].replace([3,4],'fair-')
data['overall health']=data['overall health'].replace([-1,-3],'?')
data['overall health']=data['overall health'].fillna('?')

data['sex']=data['sex'].replace([0],'Female')
data['sex']=data['sex'].replace([1],'Male')

#year_of_birth _ numeric and widely appears (numeric)

data['BMI']=data['BMI'].fillna(27.339) #this is the mean value. for a very small group of participants

data['Weight']=data['Weight'].fillna(77.85) #this is the mean value. for a very small group of participants

data['Seated height']=data['Seated height'].fillna(136.28) #this is the mean value. for a very small group of participants

data['Standing height']=data['Standing height'].fillna(168.51) #this is the mean value. for a very small group of participants

data['Systolic blood pressure']=data['Systolic blood pressure'].fillna(138.713) #this is the mean value. 
#is that ok ? there is only 48k participants in this feature on 500k overall

data['Diastolic blood pressure']=data['Diastolic blood pressure'].fillna(82.47) #this is the mean value. 
#is that ok ? there is only 48k participants in this feature on 500k overall

data['Pulse rate']=data['Pulse rate'].fillna( 70.43) #this is the mean value.
#is that ok ? there is only 48k participants in this feature on 500k overall

data['Waist circumference']=data['Waist circumference'].fillna(90.160) #this is the mean value. for a very small group of participants

data['Hip circumference']=data['Hip circumference'].fillna(103.158) #this is the mean value. for a very small group of participants

data['Urea']=data['Urea'].fillna(5.410) #this is the median value. for a very small group of participants

data['Triglycerides']=data['Triglycerides'].fillna(1.745) #this is the median value. for a very small group of participants


#codind 2171
data['hypertensive heart disease']=data['hypertensive heart disease'].replace([20,21,30,31,40,41,50,51],'indication')
data['hypertensive heart disease']=data['hypertensive heart disease'].fillna('?') 

#codind 2171
data['insulin-dependent diabetes mellitus']=data['insulin-dependent diabetes mellitus'].replace([20,21,30,31,40,41,50,51],'indication')
data['insulin-dependent diabetes mellitus']=data['insulin-dependent diabetes mellitus'].fillna('?') 
#codind 2171
data['non-insulin-dependent diabetes mellitus']=data['non-insulin-dependent diabetes mellitus'].replace([20,21,30,31,40,41,50,51],'indication')
data['non-insulin-dependent diabetes mellitus']=data['non-insulin-dependent diabetes mellitus'].fillna('?') 



#codind 2171
data['unspecified diabetes mellitus']=data['unspecified diabetes mellitus'].replace([20,21,30,31,40,41,50,51],'indication')
data['unspecified diabetes mellitus']=data['unspecified diabetes mellitus'].fillna('?') 

#codind 2171
data['osteoporosis with pathological fracture']=data['osteoporosis with pathological fracture'].replace([20,21,30,31,40,41,50,51],'indication')
data['osteoporosis with pathological fracture']=data['osteoporosis with pathological fracture'].fillna('?') 

#codind 2171
column='osteoporosis without pathological fracture'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication')
data[column]=data[column].fillna('?') 

#codind 2171
column='obesity'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication')
data[column]=data[column].fillna('?') 

#codind 2171
column='cystic fibrosis'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication')
data[column]=data[column].fillna('?') 

#codind 2171
column='subclinical iodine-deficiency hypothyroidism'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication')
data[column]=data[column].fillna('?') 

#codind 2171
column='other hypothyroidism'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication')
data[column]=data[column].fillna('?') 


#codind 100012
column='Time spent doing light physical activity'
data[column]=data[column].replace([35,57,79,912,1200],'more than 3 hours a week')
data[column]=data[column].replace([13,1,0],'less than 3 hours a week')
data[column]=data[column].fillna('?') 

#100912
column='Number of days/week of vigorous physical activity 10+ minutes'
data[column]=data[column].replace([-1,-3],1.85323)
data[column]=data[column].fillna(1.85323) 

#codind 100317
column='Frequency of walking for pleasure in last 4 weeks'
data[column]=data[column].replace([3,4,5,6],'more than once a week')
data[column]=data[column].replace([1,2],'less than once a week')
data[column]=data[column].replace([-1,-3],'?')
data[column]=data[column].fillna('?') 

#codind 100317
column='Frequency of strenuous sports in last 4 weeks'
data[column]=data[column].replace([3,4,5,6],'more than once a week')
data[column]=data[column].replace([1,2],'less than once a week')
data[column]=data[column].replace([-1,-3],'?')
data[column]=data[column].fillna('?')

data['Water intake']=data['Water intake'].fillna(2.86012) #this is the mean value. for a very small group of participants


#codind 100402
column='Alcohol intake frequency'
data[column]=data[column].replace([1,2,3],'once a week or more')
data[column]=data[column].replace([4,5,6],'less than once a week')
data[column]=data[column].replace([-3],'?')
data[column]=data[column].fillna('?') 


#codind 100307
column='Pork intake'
data[column]=data[column].replace([3,4,5],'once a week or more')
data[column]=data[column].replace([0,1,2],'less than once a week')
data[column]=data[column].replace([-1,-3],'?')
data[column]=data[column].fillna('?') 

#codind 100377
column='Lamb/mutton intake'
data[column]=data[column].replace([3,4,5],'once a week or more')
data[column]=data[column].replace([0,1,2],'less than once a week')
data[column]=data[column].replace([-1,-3],'?')
data[column]=data[column].fillna('?') 

#codind 100377
column='Beef intake'
data[column]=data[column].replace([3,4,5],'once a week or more')
data[column]=data[column].replace([0,1,2],'less than once a week')
data[column]=data[column].replace([-1,-3],'?')
data[column]=data[column].fillna('?') 

#codind 100377
column='Processed meat intake'
data[column]=data[column].replace([3,4,5],'once a week or more')
data[column]=data[column].replace([0,1,2],'less than once a week')
data[column]=data[column].replace([-1,-3],'?')
data[column]=data[column].fillna('?') 

#codind 100377
column='Oily fish intake'
data[column]=data[column].replace([3,4,5],'once a week or more')
data[column]=data[column].replace([0,1,2],'less than once a week')
data[column]=data[column].replace([-1,-3],'?')
data[column]=data[column].fillna('?') 

#codind 100377
column='Non-oily fish intake'
data[column]=data[column].replace([3,4,5],'once a week or more')
data[column]=data[column].replace([0,1,2],'less than once a week')
data[column]=data[column].replace([-1,-3],'?')
data[column]=data[column].fillna('?') 

#codind 100377
column='Poultry intake'
data[column]=data[column].replace([3,4,5],'once a week or more')
data[column]=data[column].replace([0,1,2],'less than once a week')
data[column]=data[column].replace([-1,-3],'?')
data[column]=data[column].fillna('?') 

#codind 100373
column='Fresh fruit intake'
####other numeric values unchanged..
data[column]=data[column].replace([-10],0.5) #less than 1
data[column]=data[column].replace([-1,-3],2.29546)
data[column]=data[column].fillna(2.29546) 

#codind 100373
column='Salad / raw vegetable intake'
####other numeric values unchanged..
data[column]=data[column].replace([-10],0.5) #less than 1
data[column]=data[column].replace([-1,-3],2.27306)
data[column]=data[column].fillna(2.27306) 

#codind 100373
column='Average weekly beer plus cider intake'
####other numeric values unchanged..
data[column]=data[column].replace([-1,-3],2.92535) 
data[column]=data[column].fillna(2.92535) 

#codind 100003
column='Crisp intake'
####other numeric values unchanged..
data[column]=data[column].replace([300],'3+') 
data[column]=data[column].replace([1,2],'1-2') 
data[column]=data[column].replace([555],'0-0.5') 
data[column]=data[column].fillna('?') # a lot of people

#codind 100003
column='Cheesy biscuits intake'
####other numeric values unchanged..
data[column]=data[column].replace([300],'3+') 
data[column]=data[column].replace([1,2],'1-2') 
data[column]=data[column].replace([555],'0-0.5') 
data[column]=data[column].fillna('?') # a lot of people



#codind 100006
column='Milk intake'
data[column]=data[column].replace([5,600,4,3,2,1],'more than 1 amounts') 
data[column]=data[column].replace([555],'less than 1 amouns') 
data[column]=data[column].fillna('?') # a lot of people

#codind 100629
column='Vitamin and mineral supplements'
data[column]=data[column].replace([1],'Vitamin A') 
data[column]=data[column].replace([2],'Vitamin B') 
data[column]=data[column].replace([3],'Vitamin C') 
data[column]=data[column].replace([4],'Vitamin D') 
data[column]=data[column].replace([5],'Vitamin E') 
data[column]=data[column].replace([6],'Folic acid or Folate (Vit B9)') 
data[column]=data[column].replace([7],'Multivitamins +/- minerals') 
data[column]=data[column].replace([-7],'None of the above') 
data[column]=data[column].replace([-3],'?') 
data[column]=data[column].fillna('?') # a lot of people

#codind 100329
column='Time spend outdoors in summer'
data[column]=data[column].fillna(3.93476) # a lot of people
data[column]=data[column].replace([-10],0.5)
data[column]=data[column].replace([-1,-3],3.93476)



#codind 504
column='Trouble falling or staying asleep, or sleeping too much'
data[column]=data[column].replace([3,4],'More than half the days') 
data[column]=data[column].replace([1,2],'Sometimes/not at all') 
data[column]=data[column].replace([-818],'?') 
data[column]=data[column].fillna('?') # a lot of people

#codind 504
column='Recent feelings of tiredness or low energy'
data[column]=data[column].replace([3,4],'More than half the days') 
data[column]=data[column].replace([1,2],'Sometimes/not at all') 
data[column]=data[column].replace([-818],'?') 
data[column]=data[column].fillna('?') # a lot of people

#codind 1160
column='Sleep duration'
data[column]=data[column].fillna(7.1569) # a lot of people

#codind 100343
column='Sleeplessness / insomnia'
data[column]=data[column].replace([3],'Usually') 
data[column]=data[column].replace([1,2],'Not usually') 
data[column]=data[column].replace([-3],'?') 
data[column]=data[column].fillna('?') # a lot of people

#codind 100343
column='Nap during day'
data[column]=data[column].replace([1],'Yes') 
data[column]=data[column].replace([2],'No') 
data[column]=data[column].replace([-3],'?') 
data[column]=data[column].fillna('?') # a lot of people

#codind 100343
column='Snoring'
data[column]=data[column].replace([3],'Usually') 
data[column]=data[column].replace([1,2],'Not usually') 
data[column]=data[column].replace([-3],'?') 
data[column]=data[column].replace([-1],'?') 
data[column]=data[column].fillna('?') # a lot of people

#codind 100343
column='Work hours - lumped category-0'
data[column]=data[column].replace([-1520],'15-20 hours') 
data[column]=data[column].replace([-2030],'20-30 hours') 
data[column]=data[column].replace([-3040],'30-40 hours') 
data[column]=data[column].replace([4000],'over than 40 hours') 
data[column]=data[column].fillna('?') # a lot of people



#codind 100343
column='Exposure to tobacco smoke outside home'
data[column]=data[column].fillna(0.514831) # a lot of people
data[column]=data[column].replace([-1,3],0.514831) 

#codind 100343
column='Exposure to tobacco smoke at home'
data[column]=data[column].replace([-1,3],0.493233) 
data[column]=data[column].fillna(0.493233) # a lot of people

data['Current tobacco smoking']=data['Current tobacco smoking'].replace([1],'yes')
data['Current tobacco smoking']=data['Current tobacco smoking'].replace([0,2],'no')
data['Current tobacco smoking']=data['Current tobacco smoking'].replace([-3],'?')
data['Current tobacco smoking']=data['Current tobacco smoking'].fillna('?')





#codind 100328
column='Leisure/social activities-0'
data[column]=data[column].replace([1],'Sports club or gym') 
data[column]=data[column].replace([2,3,4,5],'Religious group/Adult education class/other activity')
data[column]=data[column].replace([-7],'None of the above')
data[column]=data[column].replace([-3],'?')
data[column]=data[column].fillna('?') # a lot of people
"""
#codind 100328
column='Leisure/social activities-1'
data[column]=data[column].replace([1],'Sports club or gym') 
data[column]=data[column].replace([2,3,4,5],'Religious group/Adult education class/other activity')
data[column]=data[column].replace([-7],'None of the above')
data[column]=data[column].replace([-3],'?')
data[column]=data[column].fillna('?') # a lot of people
"""
#codind 503
column='Ever had prolonged feelings of sadness or depression'
data[column]=data[column].replace([-818],'?') 
data[column]=data[column].replace([0],'No')
data[column]=data[column].replace([1],'Yes')
data[column]=data[column].fillna('?') # a lot of people

#codind 504
column='Recent feelings of depression'
data[column]=data[column].replace([1],'no') 
data[column]=data[column].replace([2],'somedays')
data[column]=data[column].replace([3,4],'most of the time')
data[column]=data[column].replace([-818],'?')
data[column]=data[column].fillna('?') # a lot of people

#codind 100484
column='Frequency of depressed mood in last 2 weeks'
data[column]=data[column].replace([1],'not at all') 
data[column]=data[column].replace([2,3,4],'yes')
data[column]=data[column].replace([-1,-3],'?')
data[column]=data[column].fillna('?') # a lot of people


#codind 100349
column='Seen doctor (GP) for nerves, anxiety, tension or depression'
data[column]=data[column].replace([1],'Yes') 
data[column]=data[column].replace([0],'No')
data[column]=data[column].replace([-1,-3],'?')
data[column]=data[column].fillna('?') # a lot of people

#codind 100349
column='Seen a psychiatrist for nerves, anxiety, tension or depression'
data[column]=data[column].replace([1],'Yes') 
data[column]=data[column].replace([0],'No')
data[column]=data[column].replace([-1,-3],'?')
data[column]=data[column].fillna('?') # a lot of people

#codind 520
column='Tense, sore, or aching muscles during worst period of anxiety'
data[column]=data[column].replace([1],'Yes') 
data[column]=data[column].replace([0],'No')
data[column]=data[column].replace([-121],'?')
data[column]=data[column].fillna('?') # a lot of people

#codind 504
column='Recent feelings of nervousness or anxiety'
data[column]=data[column].replace([2,3,4],'Several days, most days or more') 
data[column]=data[column].replace([1],'not at all') 
data[column]=data[column].replace([-818],'?') 
data[column]=data[column].fillna('?') # a lot of people

#codind 504
column='Recent inability to stop or control worrying'
data[column]=data[column].replace([2,3,4],'Several days, most days or more') 
data[column]=data[column].replace([1],'not at all') 
data[column]=data[column].replace([-818],'?') 
data[column]=data[column].fillna('?') # a lot of people

#codind 504
column='Recent trouble relaxing'
data[column]=data[column].replace([2,3,4],'Several days, most days or more') 
data[column]=data[column].replace([1],'not at all') 
data[column]=data[column].replace([-818],'?') 
data[column]=data[column].fillna('?') # a lot of people

#codind 504
column='Recent worrying too much about different things'
data[column]=data[column].replace([2,3,4],'Several days, most days or more') 
data[column]=data[column].replace([1],'not at all') 
data[column]=data[column].replace([-818],'?') 
data[column]=data[column].fillna('?') # a lot of people

#codind 2171
column='other nonscarring hair loss'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 2171
column='Degree bothered by headaches in the last 3 months'
data[column]=data[column].replace([-600],'not bothered') 
data[column]=data[column].replace([-601,-602,-818],'bothered a little or a lot') 
data[column]=data[column].fillna('?') # a lot of people

#codind 2171
column='migraine'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 100610
column='Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor'
data[column]=data[column].replace([5],'Blood clot in the leg (DVT)') 
data[column]=data[column].replace([7],'Blood clot in the lung') 
data[column]=data[column].replace([6],'Emphysema/chronic bronchitis') 
data[column]=data[column].replace([8],'Asthma')
data[column]=data[column].replace([9],'Hayfever, allergic rhinitis or eczema')
data[column]=data[column].replace([-7],'None of the above')
data[column]=data[column].replace([-3],'?')
data[column]=data[column].fillna('?') # a lot of people

#codind 2171
column='acne'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 2171
column='cholesteatoma of middle ear'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 2171
column='stroke, not specified as haemorrhage or infarction'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people
#codind 2171
column='acute tonsillitis'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 2171
column='chronic diseases of tonsils and adenoids'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 2171
column='asthma'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 2171
column='dermatitis due to substances taken internally'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 7
column='Cough on most days'
data[column]=data[column].replace([1],'yes') 
data[column]=data[column].replace([0],'no') 
data[column]=data[column].fillna('?') # a lot of people

#codind 2171
column='pneumonia due to streptococcus pneumoniae'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people




#codind 339
column='Degree bothered by chest pain in the last 3 months'
data[column]=data[column].astype(str)

data[column]=data[column].replace(['-600.0'],'not bothered') 
data[column]=data[column].replace(['-601.0','-602.0'],'bothered') 
data[column]=data[column].replace(['-818.0','nan'],'?') 
data[column]=data[column].fillna('?') # a lot of people




#codind 2171
column='crohns disease'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 2171
column='ulcerative colitis'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 2171
column='candidiasis'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 100628
column='Medication for pain relief, constipation, heartburn'
data[column]=data[column].replace([1,2,3,4,5,6],'Aspirin,Ibuprofen,Paracetamol,Ranitidine,Omeprazole,Laxatives') 
data[column]=data[column].replace([-7],'None of the above') 
data[column]=data[column].replace([-1,-3],'?') 
data[column]=data[column].fillna('?') # a lot of people

#codind 2171
column='acute hepatitis a'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 2171
column='acute hepatitis b'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people
#codind 2171
column='other acute viral hepatitis'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 2171
column='male infertility'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 2171
column='female infertility'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 339
column='Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones'
data[column]=data[column].replace([1],'Cholesterol lowering medication') 
data[column]=data[column].replace([2],'Blood pressure medication') 
data[column]=data[column].replace([3],'Insulin') 
data[column]=data[column].replace([4],'Hormone replacement therapy') 
data[column]=data[column].replace([5],'Oral contraceptive pill or minipill') 
data[column]=data[column].replace([-7],'None of the above') 
data[column]=data[column].replace([-1,-3],'?') 
data[column]=data[column].fillna('?') # a lot of people


#codind 2171
column='varicose veins of lower extremities'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people
#codind 2171
column='varicose veins of other sites'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people

#codind 2171
column='psoriasis'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people


#codind 2171
column='nail disorders'
data[column]=data[column].replace([20,21,30,31,40,41,50,51],'indication') 
data[column]=data[column].fillna('control group') # a lot of people





print(data)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (98) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0  ...                                    icd_other_codes
# 0                0  ...                  {'', 'UNKNOWN', '1000010', 'nan'}
# 1                1  ...  {'', 'W110', 'R42', 'N943', 'Z301', 'Z924', 'K...
# 2                2  ...                  {'', 'UNKNOWN', 'nan', '1000034'}
# 3                3  ...          {'', 'E221', 'UNKNOWN', 'nan', '1000045'}
# 4                4  ...  {'', 'G473', 'I10', 'R69', 'UNKNOWN', 'nan', '...
# ...            ...  ...                                                ...
# 502500      502500  ...  {'', 'K409', '6025016', 'UNKNOWN', 'K589', 'na...
# 502501      502501  ...  {'N393', '', 'N815', 'UNKNOWN', 'N765', '60250...
# ...

# %%
# !pip install tableone

# %%
columns = ['NAFLD-IND','overall health', 'sex','BMI','Weight','Seated height','Standing height','Systolic blood pressure','Diastolic blood pressure','Pulse rate','Waist circumference','Hip circumference','Urea','Triglycerides','hypertensive heart disease','insulin-dependent diabetes mellitus','non-insulin-dependent diabetes mellitus','unspecified diabetes mellitus',
'osteoporosis with pathological fracture','osteoporosis without pathological fracture',
'obesity','cystic fibrosis','subclinical iodine-deficiency hypothyroidism',
'other hypothyroidism','Time spent doing light physical activity',
'Number of days/week of moderate physical activity 10+ minutes',
'Frequency of walking for pleasure in last 4 weeks',
'Frequency of strenuous sports in last 4 weeks',
'Water intake',
'Alcohol intake frequency',
'Pork intake','Lamb/mutton intake','Beef intake','Processed meat intake',
'Oily fish intake','Non-oily fish intake','Poultry intake',
'Fresh fruit intake','Salad / raw vegetable intake',
'Average weekly beer plus cider intake',
'Crisp intake','Cheesy biscuits intake','Milk intake',
'Vitamin and mineral supplements',

'Time spend outdoors in summer','Trouble falling or staying asleep, or sleeping too much',
'Recent feelings of tiredness or low energy','Sleep duration',
'Sleeplessness / insomnia','Nap during day','Snoring',
'Work hours - lumped category-0','Exposure to tobacco smoke outside home','Exposure to tobacco smoke at home',
'Current tobacco smoking','Leisure/social activities-0',
'Ever had prolonged feelings of sadness or depression','Recent feelings of depression',
'Frequency of depressed mood in last 2 weeks','Seen doctor (GP) for nerves, anxiety, tension or depression',
'Seen a psychiatrist for nerves, anxiety, tension or depression','Tense, sore, or aching muscles during worst period of anxiety',
'Recent feelings of nervousness or anxiety','Recent inability to stop or control worrying',
'Recent trouble relaxing','Recent worrying too much about different things','other nonscarring hair loss',
'Degree bothered by headaches in the last 3 months','migraine',
'Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor',
'acne','cholesteatoma of middle ear','stroke, not specified as haemorrhage or infarction',
'acute tonsillitis','chronic diseases of tonsils and adenoids','asthma',
'dermatitis due to substances taken internally','Cough on most days',
'pneumonia due to streptococcus pneumoniae',
'candidiasis','Medication for pain relief, constipation, heartburn','acute hepatitis a',
'acute hepatitis b','other acute viral hepatitis','male infertility','female infertility',
'Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones','varicose veins of lower extremities',
'varicose veins of other sites','psoriasis','nail disorders','Degree bothered by chest pain in the last 3 months',
'crohns disease','ulcerative colitis'
]

categorical=['NAFLD-IND','overall health', 'sex',
'hypertensive heart disease','insulin-dependent diabetes mellitus',
'non-insulin-dependent diabetes mellitus','unspecified diabetes mellitus',
'osteoporosis with pathological fracture','osteoporosis without pathological fracture',
'obesity','cystic fibrosis','subclinical iodine-deficiency hypothyroidism',
'other hypothyroidism','Time spent doing light physical activity',
'Frequency of walking for pleasure in last 4 weeks',
'Frequency of strenuous sports in last 4 weeks',
'Alcohol intake frequency',
'Pork intake','Lamb/mutton intake','Beef intake','Processed meat intake',
'Oily fish intake','Non-oily fish intake','Poultry intake',

'Crisp intake','Cheesy biscuits intake','Milk intake',
'Vitamin and mineral supplements',
'Trouble falling or staying asleep, or sleeping too much',
'Recent feelings of tiredness or low energy',
'Sleeplessness / insomnia','Nap during day','Snoring',
'Work hours - lumped category-0',
'Current tobacco smoking','Leisure/social activities-0',
'Ever had prolonged feelings of sadness or depression','Recent feelings of depression',
'Frequency of depressed mood in last 2 weeks','Seen doctor (GP) for nerves, anxiety, tension or depression',
'Seen a psychiatrist for nerves, anxiety, tension or depression','Tense, sore, or aching muscles during worst period of anxiety',
'Recent feelings of nervousness or anxiety','Recent inability to stop or control worrying',
'Recent trouble relaxing','Recent worrying too much about different things','other nonscarring hair loss',
'Degree bothered by headaches in the last 3 months','migraine',
'Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor',
'acne','cholesteatoma of middle ear','stroke, not specified as haemorrhage or infarction',
'acute tonsillitis','chronic diseases of tonsils and adenoids','asthma',
'dermatitis due to substances taken internally','Cough on most days',
'pneumonia due to streptococcus pneumoniae',
'Degree bothered by chest pain in the last 3 months','crohns disease','ulcerative colitis',
'candidiasis','Medication for pain relief, constipation, heartburn','acute hepatitis a',
'acute hepatitis b','other acute viral hepatitis','male infertility','female infertility',
'Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones',
'varicose veins of lower extremities','varicose veins of other sites','psoriasis',
'nail disorders'

]

"""
data["NAFLD"] = data["NAFLD"].astype('string')
columns2=data.columns
for item in columns2:
  print(item)
  print(data[column].dtype)
"""
groupby = 'NAFLD-IND'

from tableone import TableOne
mytable = TableOne(data,columns=columns,categorical=categorical,groupby=groupby)

#mytable = TableOne(data,columns=columns,categorical=categorical,groupby=groupby,pval=True)
print(mytable.tabulate(tablefmt="grid"))
mytable.to_csv("my_tableone.csv")
data.to_csv("data.csv")

# %%
mytable = TableOne(data,columns=columns,categorical=categorical,groupby=groupby,smd=True)

#mytable = TableOne(data,columns=columns,categorical=categorical,groupby=groupby,pval=True)
print(mytable.tabulate(tablefmt="grid"))
mytable.to_csv("my_tableone.csv")
data.to_csv("data.csv")
# Out:
# +------------------------------------------------------------------------------------------------------+---------------------------------------------------------------+-----------+----------------+----------------+--------------+--------------+-------------------------+---------------------------+---------------------------+
# |                                                                                                      |                                                               | Missing   | Overall        | CONTROL        | NAFLD-IND    | UNKNOWN      | SMD (CONTROL,UNKNOWN)   | SMD (NAFLD-IND,UNKNOWN)   | SMD (CONTROL,NAFLD-IND)   |
# +======================================================================================================+===============================================================+===========+================+================+==============+==============+=========================+===========================+===========================+
# ...

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

data=pd.read_csv("data.csv")

df=data
df=df.drop(df.columns[0],axis=1)
df=df.drop(df.columns[0], axis=1)
df=df.drop('eid', axis=1)
df=df.drop('transitory neonatal disorders of calcium and magnesium metabolism', axis=1)

#for now - reove icd code..
#will bring them back later
df=df.drop('icd_other_codes', axis=1)
df=df.drop('icd_codes', axis=1)
df=df.drop('eid.1', axis=1)
#
#

print(df.shape)
df=df[[c for c in df if c not in ['NAFLD-IND']] + ['NAFLD-IND']] #predict 

print(df.dtypes)
categorical_feature_mask=[]
for feature in df.columns[:-1]:
  if df[feature].dtype==object:
    categorical_feature_mask.append(feature)

#categorical_feature_mask = df.dtypes==object

for feature in categorical_feature_mask:
  df=pd.get_dummies(df, columns=[feature])

for feature in df.columns:
  if df[feature].dtype==float:
    df[feature]=df[feature].fillna(-100) # a lot of people

print(df.shape)
print(df)
df.to_csv("df.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (99) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (502505, 97)
# sex                                            object
# YearOfBirth                                   float64
# Waist circumference                           float64
# Hip circumference                             float64
# Standing height                               float64
#                                                ...
# osteoporosis with pathological fracture        object
# osteoporosis without pathological fracture     object
# male infertility                               object
# female infertility                             object
# NAFLD-IND                                      object
# Length: 97, dtype: object
# (502505, 231)
#         YearOfBirth  ...  female infertility_indication
# ...

# %%
#continue with first modelling comaprision :)
#https://colab.research.google.com/drive/1H16Xvyo_tpVQ-ccorGSBR_imB9pSxhhu

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import mean_squared_error as mse
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import LinearSVC
from sklearn.ensemble import VotingClassifier
from sklearn.feature_selection import RFECV

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df=pd.read_csv("df.csv")
print(df.shape)
columns=df.columns

X=df.iloc[:,-1:] #maybe change it to X=df.drop(columns=['s1y'])
# Out:
# (502505, 232)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(df['NAFLD-IND'],label="Sum")

plt.show()
df.shape
# Out:
# (502505, 232)

# %%
#this ruins the specifity of the model..

df['NAFLD-IND']=df['NAFLD-IND'].map({'NAFLD-IND':1,'CONTROL':0,'UNKNOWN':1})
y=df['NAFLD-IND']

# %%
df=df.dropna()
col_labels=df.columns
for c in col_labels:
    no_missing = df[c].isnull().sum()
    if no_missing > 0:
        print(c)
        print(no_missing)
df.shape
# Out:
# (502505, 232)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.34)

#import sklearn.metrics
#sorted(sklearn.metrics.SCORERS.keys())

# %%
LR = LogisticRegression()

scoring = ['accuracy', 'precision_macro', 'recall_macro' , 'f1_weighted', 'roc_auc','balanced_accuracy']
scores = cross_validate(LR, X_train, y_train, scoring=scoring, cv=20)

sorted(scores.keys())
LR_fit_time = scores['fit_time'].mean()
LR_score_time = scores['score_time'].mean()
LR_accuracy = scores['test_accuracy'].mean()
LR_precision = scores['test_precision_macro'].mean()
LR_recall = scores['test_recall_macro'].mean()
LR_f1 = scores['test_f1_weighted'].mean()
LR_roc = scores['test_roc_auc'].mean()
LR_ba = scores['test_balanced_accuracy'].mean()

# %%
decision_tree = DecisionTreeClassifier()

scoring = ['accuracy', 'precision_macro', 'recall_macro' , 'f1_weighted', 'roc_auc','balanced_accuracy']
scores = cross_validate(decision_tree, X_train, y_train, scoring=scoring, cv=20)

sorted(scores.keys())
dtree_fit_time = scores['fit_time'].mean()
dtree_score_time = scores['score_time'].mean()
dtree_accuracy = scores['test_accuracy'].mean()
dtree_precision = scores['test_precision_macro'].mean()
dtree_recall = scores['test_recall_macro'].mean()
dtree_f1 = scores['test_f1_weighted'].mean()
dtree_roc = scores['test_roc_auc'].mean()
dtree_ba = scores['test_balanced_accuracy'].mean()

# %%
SVM = SVC(probability = True)

scoring = ['accuracy','precision_macro', 'recall_macro' , 'f1_weighted', 'roc_auc','balanced_accuracy']
scores = cross_validate(SVM, X_train, y_train, scoring=scoring, cv=2)

sorted(scores.keys())
SVM_fit_time = scores['fit_time'].mean()
SVM_score_time = scores['score_time'].mean()
SVM_accuracy = scores['test_accuracy'].mean()
SVM_precision = scores['test_precision_macro'].mean()
SVM_recall = scores['test_recall_macro'].mean()
SVM_f1 = scores['test_f1_weighted'].mean()
SVM_roc = scores['test_roc_auc'].mean()
SVM_ba = scores['test_balanced_accuracy'].mean()

# %%
LDA = LinearDiscriminantAnalysis()

scoring = ['accuracy', 'precision_macro', 'recall_macro' , 'f1_weighted', 'roc_auc','balanced_accuracy']
scores = cross_validate(LDA, X_train, y_train, scoring=scoring, cv=20)

sorted(scores.keys())
LDA_fit_time = scores['fit_time'].mean()
LDA_score_time = scores['score_time'].mean()
LDA_accuracy = scores['test_accuracy'].mean()
LDA_precision = scores['test_precision_macro'].mean()
LDA_recall = scores['test_recall_macro'].mean()
LDA_f1 = scores['test_f1_weighted'].mean()
LDA_roc = scores['test_roc_auc'].mean()
LDA_ba = scores['test_balanced_accuracy'].mean()

# %%
random_forest = RandomForestClassifier()

scoring = ['accuracy', 'precision_macro', 'recall_macro' , 'f1_weighted', 'roc_auc','balanced_accuracy']
scores = cross_validate(random_forest, X_train, y_train, scoring=scoring, cv=20)

sorted(scores.keys())
forest_fit_time = scores['fit_time'].mean()
forest_score_time = scores['score_time'].mean()
forest_accuracy = scores['test_accuracy'].mean()
forest_precision = scores['test_precision_macro'].mean()
forest_recall = scores['test_recall_macro'].mean()
forest_f1 = scores['test_f1_weighted'].mean()
forest_roc = scores['test_roc_auc'].mean()
forest_ba = scores['test_balanced_accuracy'].mean()

# %%
bayes = GaussianNB()

scoring = ['accuracy', 'precision_macro', 'recall_macro' , 'f1_weighted', 'roc_auc','balanced_accuracy']
scores = cross_validate(bayes, X_train, y_train, scoring=scoring, cv=3)

sorted(scores.keys())
bayes_fit_time = scores['fit_time'].mean()
bayes_score_time = scores['score_time'].mean()
bayes_accuracy = scores['test_accuracy'].mean()
bayes_precision = scores['test_precision_macro'].mean()
bayes_recall = scores['test_recall_macro'].mean()
bayes_f1 = scores['test_f1_weighted'].mean()
bayes_roc = scores['test_roc_auc'].mean()
bayes_ba = scores['test_balanced_accuracy'].mean()

# %%
models_initial = pd.DataFrame({
    'Model'       : ['Logistic Regression', 'Decision Tree', 'Support Vector Machine', 'Linear Discriminant Analysis','Random Forest',  'Bayes'],
    'Fitting time': [LR_fit_time, dtree_fit_time, SVM_fit_time, LDA_fit_time, forest_fit_time, bayes_fit_time],
    'Scoring time': [LR_score_time, dtree_score_time, SVM_score_time, LDA_score_time, forest_score_time, bayes_score_time],
    'Accuracy'    : [LR_accuracy, dtree_accuracy, SVM_accuracy, LDA_accuracy, forest_accuracy, bayes_accuracy],
    'Precision'   : [LR_precision, dtree_precision, SVM_precision, LDA_precision, forest_precision, bayes_precision],
    'Recall'      : [LR_recall, dtree_recall, SVM_recall, LDA_recall, forest_recall, bayes_recall],
    'F1_score'    : [LR_f1, dtree_f1, SVM_f1, LDA_f1, forest_f1, bayes_f1],
    'AUC_ROC'     : [LR_roc, dtree_roc, SVM_roc, LDA_roc, forest_roc, bayes_roc],
    'balanced accuracy'     : [LR_ba, dtree_ba, SVM_ba, LDA_ba, forest_ba, bayes_ba],
    }, columns = ['Model', 'Fitting time', 'Scoring time', 'Accuracy', 'Precision', 'Recall', 'F1_score', 'AUC_ROC','balanced accuracy'])

models_initial.sort_values(by='Accuracy', ascending=False)
# Out:
#                           Model  Fitting time  ...   AUC_ROC  balanced accuracy
# 0           Logistic Regression      1.192434  ...  0.500739           0.500000
# 1                 Decision Tree      0.047219  ...  0.500739           0.500000
# 3  Linear Discriminant Analysis      0.104773  ...  0.500739           0.500000
# 4                 Random Forest      4.537456  ...  0.500739           0.500000
# 2        Support Vector Machine    175.100892  ...  0.500000           0.500000
# 5                         Bayes      0.027926  ...  0.500738           0.500738
#
# [6 rows x 9 columns]

# %%
#contiue in random search for best hyperparameters in
#https://colab.research.google.com/drive/1H16Xvyo_tpVQ-ccorGSBR_imB9pSxhhu#scrollTo=w3Z-Gs-FoHFE
